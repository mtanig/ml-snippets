# %% [markdown]
# # Predict CTR
# Dataset: https://msnews.github.io/#getting-start
#
# Use small data this time.

# %% [markdown]
# ## Prepare datasets

# %%
# !ls
# Out:
# MINDsmall_dev.zip   MINDsmall_train.zip Untitled.ipynb

# %%
# !mkdir MINDsmall_train MINDsmall_dev
# Out:
# mkdir: MINDsmall_train: File exists
# mkdir: MINDsmall_dev: File exists

# %%
# !unzip MINDsmall_train.zip -d MINDsmall_train
# Out:
# Archive:  MINDsmall_train.zip
#   inflating: MINDsmall_train/entity_embedding.vec
#   inflating: MINDsmall_train/news.tsv
#   inflating: MINDsmall_train/relation_embedding.vec
#   inflating: MINDsmall_train/behaviors.tsv

# %%
# !unzip MINDsmall_dev.zip -d MINDsmall_dev
# Out:
# Archive:  MINDsmall_dev.zip
#   inflating: MINDsmall_dev/behaviors.tsv
#   inflating: MINDsmall_dev/entity_embedding.vec
#   inflating: MINDsmall_dev/news.tsv
#   inflating: MINDsmall_dev/relation_embedding.vec

# %%
# pip install sentence-transformers lightgbm pandas tqdm scikit-learn tables

# %% [markdown]
# ## Experiments

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from tqdm import tqdm
tqdm.pandas()

# %% [markdown]
# ### Ensemble(text vector + other features -> GBDT)

# %% [markdown]
# ### E5でベクトル化 → HDF5保存
# HDF5を使うことで部分読み込みができるようになり、省メモリ化できた。30G+ -> 20G。しかしまだ足りなかったのでデータを分割処理バッチ学習に変更。

# %%
# ニュースデータ読み込み（MINDのnews.tsv想定）
news = pd.read_table("MINDsmall_train/news.tsv", names=["id", "cat", "subcat", "title", "abstract", "url", "title_entities", "abstract_entities"])

# %%
# モデル読み込み（例：E5-base）
embedder = SentenceTransformer("intfloat/e5-base")

# タイトルをE5ベクトル化
embeddings = embedder.encode(
    ["query: " + t for t in news["title"].fillna("")], 
    batch_size=64, 
    show_progress_bar=True
)

# ベクトル＋news_idでDataFrame化
vec_df = pd.DataFrame(embeddings)
vec_df.insert(0, "news_id", news["id"].values)

# HDF5に保存
vec_df.to_hdf("news_vectors.h5", key="vecs", mode="w")

# %%
### CTRデータに出てくる news_id だけ読み込む

# %%
# CTRログ読み込み（MINDのbehaviors.tsv想定）
ctr_df = pd.read_table("MINDsmall_train/behaviors.tsv", names=["imp_id", "user_id", "time", "history", "impressions"])

# impressions を展開してクリックデータに
def parse_impressions(row):
    pairs = row["impressions"].split()  # ← 修正済み
    data = []
    for pair in pairs:
        nid, label = pair.split("-")
        data.append((row["imp_id"], row["user_id"], nid, int(label)))
    return data

ctr_data = []
for _, row in ctr_df.iterrows():
    ctr_data.extend(parse_impressions(row))

# DataFrameに変換
ctr_df = pd.DataFrame(ctr_data, columns=["imp_id", "user_id", "news_id", "label"])

# 使用されている news_id のみ取得
used_news_ids = ctr_df["news_id"].unique()

# 対象のベクトルだけを部分読み込み
vec_df = pd.read_hdf("news_vectors.h5", key="vecs")
vec_df = vec_df[vec_df["news_id"].isin(used_news_ids)]

# %%
### 特徴量構築
# pd.merge を使わず、news_id → ベクトル の辞書にして map＋list で追加する(map + dict + vstack)方が圧倒的に軽量。
# しかしまだ足りなかったのでデータを分割処理バッチ学習に変更

# %%
# # カテゴリ情報のマージ
# news_cat_map = news.set_index("id")["cat"].to_dict()
# ctr_df["cat"] = ctr_df["news_id"].map(news_cat_map)
# cat_dummies = pd.get_dummies(ctr_df["cat"], prefix="cat")

# # ベクトルを辞書化してmapで追加（メモリ効率）
# vec_dict = dict(zip(vec_df["news_id"], vec_df.drop(columns=["news_id"]).values))
# vec_dim = len(next(iter(vec_dict.values())))
# vec_cols = [f'vec_{i}' for i in range(vec_dim)]

# # 欠損処理しながらベクトルを列展開
# vec_filled = [vec_dict.get(nid, np.zeros(vec_dim)) for nid in ctr_df["news_id"]]
# vec_matrix = np.vstack(vec_filled) <-- ここでメモリを消費
# vec_df_expanded = pd.DataFrame(vec_matrix, columns=vec_cols)

# # 最終特徴量
# X = pd.concat([vec_df_expanded, cat_dummies], axis=1)
# y = ctr_df["label"]

# %%
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
from sklearn.metrics import roc_auc_score
from sklearn.utils import shuffle

# ---------- 準備 ----------
news_cat_map = news.set_index("id")["cat"].to_dict()
ctr_df["cat"] = ctr_df["news_id"].map(news_cat_map)
all_cats = sorted(ctr_df["cat"].dropna().unique())

vec_dict = dict(zip(vec_df["news_id"], vec_df.drop(columns=["news_id"]).values))
vec_dim = len(next(iter(vec_dict.values())))
vec_cols = [f"vec_{i}" for i in range(vec_dim)]

batch_size = 100_000
ctr_df = shuffle(ctr_df, random_state=42)

# ---------- バリデーションデータを分ける ----------
val_df = ctr_df.iloc[-batch_size:].copy()
train_df = ctr_df.iloc[:-batch_size].copy()

val_df["cat"] = pd.Categorical(val_df["news_id"].map(news_cat_map), categories=all_cats)
val_cat_dummies = pd.get_dummies(val_df["cat"], prefix="cat").astype("float32").reindex(val_df.index).fillna(0)
val_vec_matrix = np.vstack([vec_dict.get(nid, np.zeros(vec_dim)) for nid in val_df["news_id"]])
val_vec_df = pd.DataFrame(val_vec_matrix, columns=vec_cols, index=val_df.index)
X_val = pd.concat([val_vec_df, val_cat_dummies], axis=1).fillna(0)
y_val = val_df["label"]

# ---------- LightGBM パラメータ ----------
params = {
    "objective": "binary",
    "metric": "auc",
    "verbosity": -1,
    "boosting_type": "gbdt",
    "learning_rate": 0.1,
    "num_leaves": 31,
    "seed": 42,
}

model = None  # 初期モデル

# ---------- バッチ学習ループ ----------
for i, start in enumerate(range(0, len(train_df), batch_size)):
    end = start + batch_size
    batch = train_df.iloc[start:end].copy()

    batch["cat"] = pd.Categorical(batch["news_id"].map(news_cat_map), categories=all_cats)
    cat_dummies = pd.get_dummies(batch["cat"], prefix="cat").astype("float32").reindex(batch.index).fillna(0)

    vec_matrix = np.vstack([vec_dict.get(nid, np.zeros(vec_dim)) for nid in batch["news_id"]])
    vec_df_expanded = pd.DataFrame(vec_matrix, columns=vec_cols, index=batch.index)

    X_batch = pd.concat([vec_df_expanded, cat_dummies], axis=1).fillna(0)
    y_batch = batch["label"]

    lgb_train = lgb.Dataset(X_batch, label=y_batch, free_raw_data=True)

    model = lgb.train(
        params,
        train_set=lgb_train,
        num_boost_round=100,  # 多めにしてもOK
        valid_sets=[lgb_train, lgb.Dataset(X_val, label=y_val)],
        valid_names=["train", "valid"],
        init_model=model,
        callbacks=[
            early_stopping(stopping_rounds=10),
            log_evaluation(10)
        ]
    )

    # 中間AUC出力
    y_pred = model.predict(X_val)
    auc = roc_auc_score(y_val, y_pred)
    print(f"[Batch {i+1}] Validation AUC: {auc:.4f}")
# Out:
# Training until validation scores don't improve for 10 rounds
# [10]	train's auc: 0.743098	valid's auc: 0.675925
# [20]	train's auc: 0.768825	valid's auc: 0.682023
# [30]	train's auc: 0.782209	valid's auc: 0.682605
# Early stopping, best iteration is:
# [23]	train's auc: 0.773617	valid's auc: 0.68295
# [Batch 1] Validation AUC: 0.6830
# Training until validation scores don't improve for 10 rounds
# [30]	train's auc: 0.727969	valid's auc: 0.688009
# [40]	train's auc: 0.759948	valid's auc: 0.690242
# [50]	train's auc: 0.776317	valid's auc: 0.69035
# Early stopping, best iteration is:
# [42]	train's auc: 0.76436	valid's auc: 0.690463
# [Batch 2] Validation AUC: 0.6905
# Training until validation scores don't improve for 10 rounds
# [50]	train's auc: 0.731606	valid's auc: 0.694877
# [60]	train's auc: 0.760139	valid's auc: 0.695443
# Early stopping, best iteration is:
# [58]	train's auc: 0.755822	valid's auc: 0.695577
# [Batch 3] Validation AUC: 0.6956
# Training until validation scores don't improve for 10 rounds
# [60]	train's auc: 0.709082	valid's auc: 0.696899
# [70]	train's auc: 0.748409	valid's auc: 0.698673
# [80]	train's auc: 0.769007	valid's auc: 0.698529
# Early stopping, best iteration is:
# [77]	train's auc: 0.764186	valid's auc: 0.699315
# [Batch 4] Validation AUC: 0.6993
# Training until validation scores don't improve for 10 rounds
# [80]	train's auc: 0.710154	valid's auc: 0.700753
# [90]	train's auc: 0.745007	valid's auc: 0.702088
# [100]	train's auc: 0.763911	valid's auc: 0.700813
# Early stopping, best iteration is:
# [91]	train's auc: 0.747601	valid's auc: 0.70229
# [Batch 5] Validation AUC: 0.7023
# Training until validation scores don't improve for 10 rounds
# [100]	train's auc: 0.730447	valid's auc: 0.70373
# Early stopping, best iteration is:
# [98]	train's auc: 0.723639	valid's auc: 0.703776
# [Batch 6] Validation AUC: 0.7038
# Training until validation scores don't improve for 10 rounds
# [100]	train's auc: 0.705492	valid's auc: 0.704554
# [110]	train's auc: 0.741622	valid's auc: 0.703403
# Early stopping, best iteration is:
# [101]	train's auc: 0.709933	valid's auc: 0.704885
# [Batch 7] Validation AUC: 0.7049
# Training until validation scores don't improve for 10 rounds
# [110]	train's auc: 0.730342	valid's auc: 0.706217
# [120]	train's auc: 0.751888	valid's auc: 0.705017
# Early stopping, best iteration is:
# [110]	train's auc: 0.730342	valid's auc: 0.706217
# [Batch 8] Validation AUC: 0.7062
# Training until validation scores don't improve for 10 rounds
# [120]	train's auc: 0.738402	valid's auc: 0.706315
# Early stopping, best iteration is:
# [116]	train's auc: 0.726055	valid's auc: 0.707295
# [Batch 9] Validation AUC: 0.7073
# Training until validation scores don't improve for 10 rounds
# [120]	train's auc: 0.716816	valid's auc: 0.707455
# [130]	train's auc: 0.74753	valid's auc: 0.705235
# Early stopping, best iteration is:
# [122]	train's auc: 0.724642	valid's auc: 0.707644
# [Batch 10] Validation AUC: 0.7076
# Training until validation scores don't improve for 10 rounds
# [130]	train's auc: 0.738191	valid's auc: 0.708442
# Early stopping, best iteration is:
# [125]	train's auc: 0.720549	valid's auc: 0.708697
# [Batch 11] Validation AUC: 0.7087
# Training until validation scores don't improve for 10 rounds
# [130]	train's auc: 0.725172	valid's auc: 0.707985
# Early stopping, best iteration is:
# [127]	train's auc: 0.712353	valid's auc: 0.708698
# [Batch 12] Validation AUC: 0.7087
# Training until validation scores don't improve for 10 rounds
# [130]	train's auc: 0.7182	valid's auc: 0.708436
# [140]	train's auc: 0.748973	valid's auc: 0.707891
# Early stopping, best iteration is:
# [135]	train's auc: 0.735717	valid's auc: 0.708749
# [Batch 13] Validation AUC: 0.7087
# Training until validation scores don't improve for 10 rounds
# [140]	train's auc: 0.718231	valid's auc: 0.707995
# Early stopping, best iteration is:
# [136]	train's auc: 0.700817	valid's auc: 0.70872
# [Batch 14] Validation AUC: 0.7087
# Training until validation scores don't improve for 10 rounds
# [140]	train's auc: 0.722745	valid's auc: 0.708524
# [150]	train's auc: 0.751012	valid's auc: 0.707553
# Early stopping, best iteration is:
# [143]	train's auc: 0.732913	valid's auc: 0.709013
# [Batch 15] Validation AUC: 0.7090
# Training until validation scores don't improve for 10 rounds
# [150]	train's auc: 0.728771	valid's auc: 0.708348
# Early stopping, best iteration is:
# [144]	train's auc: 0.704562	valid's auc: 0.708503
# [Batch 16] Validation AUC: 0.7085
# Training until validation scores don't improve for 10 rounds
# [150]	train's auc: 0.725142	valid's auc: 0.709315
# [160]	train's auc: 0.750468	valid's auc: 0.707555
# Early stopping, best iteration is:
# [152]	train's auc: 0.731424	valid's auc: 0.709629
# [Batch 17] Validation AUC: 0.7096
# Training until validation scores don't improve for 10 rounds
# [160]	train's auc: 0.73525	valid's auc: 0.709933
# Early stopping, best iteration is:
# [156]	train's auc: 0.722585	valid's auc: 0.710362
# [Batch 18] Validation AUC: 0.7104
# Training until validation scores don't improve for 10 rounds
# [160]	train's auc: 0.722307	valid's auc: 0.71011
# Early stopping, best iteration is:
# [157]	train's auc: 0.710423	valid's auc: 0.710816
# [Batch 19] Validation AUC: 0.7108
# Training until validation scores don't improve for 10 rounds
# [160]	train's auc: 0.720257	valid's auc: 0.711781
# [170]	train's auc: 0.749394	valid's auc: 0.711449
# Early stopping, best iteration is:
# [163]	train's auc: 0.731314	valid's auc: 0.712135
# [Batch 20] Validation AUC: 0.7121
# Training until validation scores don't improve for 10 rounds
# [170]	train's auc: 0.729824	valid's auc: 0.711487
# Early stopping, best iteration is:
# [166]	train's auc: 0.714955	valid's auc: 0.711927
# [Batch 21] Validation AUC: 0.7119
# Training until validation scores don't improve for 10 rounds
# [170]	train's auc: 0.725476	valid's auc: 0.711625
# Early stopping, best iteration is:
# [168]	train's auc: 0.717216	valid's auc: 0.711889
# [Batch 22] Validation AUC: 0.7119
# Training until validation scores don't improve for 10 rounds
# [170]	train's auc: 0.720637	valid's auc: 0.711915
# [180]	train's auc: 0.750538	valid's auc: 0.710833
# Early stopping, best iteration is:
# [171]	train's auc: 0.724233	valid's auc: 0.712024
# [Batch 23] Validation AUC: 0.7120
# Training until validation scores don't improve for 10 rounds
# [180]	train's auc: 0.737303	valid's auc: 0.709949
# Early stopping, best iteration is:
# [172]	train's auc: 0.709527	valid's auc: 0.711821
# [Batch 24] Validation AUC: 0.7118
# Training until validation scores don't improve for 10 rounds
# [180]	train's auc: 0.737157	valid's auc: 0.711389
# Early stopping, best iteration is:
# [174]	train's auc: 0.71574	valid's auc: 0.712086
# [Batch 25] Validation AUC: 0.7121
# Training until validation scores don't improve for 10 rounds
# [180]	train's auc: 0.730758	valid's auc: 0.71047
# Early stopping, best iteration is:
# [175]	train's auc: 0.711389	valid's auc: 0.711693
# [Batch 26] Validation AUC: 0.7117
# Training until validation scores don't improve for 10 rounds
# [180]	train's auc: 0.722634	valid's auc: 0.711461
# Early stopping, best iteration is:
# [176]	train's auc: 0.705566	valid's auc: 0.711803
# [Batch 27] Validation AUC: 0.7118
# Training until validation scores don't improve for 10 rounds
# [180]	train's auc: 0.722925	valid's auc: 0.711344
# Early stopping, best iteration is:
# [177]	train's auc: 0.710741	valid's auc: 0.711788
# [Batch 28] Validation AUC: 0.7118
# Training until validation scores don't improve for 10 rounds
# [180]	train's auc: 0.709918	valid's auc: 0.711154
# Early stopping, best iteration is:
# [178]	train's auc: 0.70095	valid's auc: 0.712023
# [Batch 29] Validation AUC: 0.7120
# Training until validation scores don't improve for 10 rounds
# [180]	train's auc: 0.710993	valid's auc: 0.711951
# Early stopping, best iteration is:
# [179]	train's auc: 0.706636	valid's auc: 0.712007
# [Batch 30] Validation AUC: 0.7120
# [180]	train's auc: 0.714707	valid's auc: 0.712045
# Training until validation scores don't improve for 10 rounds
# [190]	train's auc: 0.747478	valid's auc: 0.712065
# Early stopping, best iteration is:
# [186]	train's auc: 0.736072	valid's auc: 0.712466
# [Batch 31] Validation AUC: 0.7125
# Training until validation scores don't improve for 10 rounds
# [190]	train's auc: 0.729918	valid's auc: 0.713285
# [200]	train's auc: 0.755101	valid's auc: 0.71112
# Early stopping, best iteration is:
# [190]	train's auc: 0.729918	valid's auc: 0.713285
# [Batch 32] Validation AUC: 0.7133
# Training until validation scores don't improve for 10 rounds
# [200]	train's auc: 0.735023	valid's auc: 0.710715
# Early stopping, best iteration is:
# [191]	train's auc: 0.701495	valid's auc: 0.71319
# [Batch 33] Validation AUC: 0.7132
# Training until validation scores don't improve for 10 rounds
# [200]	train's auc: 0.735624	valid's auc: 0.710935
# Early stopping, best iteration is:
# [192]	train's auc: 0.706728	valid's auc: 0.713123
# [Batch 34] Validation AUC: 0.7131
# Training until validation scores don't improve for 10 rounds
# [200]	train's auc: 0.736904	valid's auc: 0.712679
# Early stopping, best iteration is:
# [197]	train's auc: 0.727503	valid's auc: 0.713361
# [Batch 35] Validation AUC: 0.7134
# Training until validation scores don't improve for 10 rounds
# [200]	train's auc: 0.718107	valid's auc: 0.713499
# [210]	train's auc: 0.746481	valid's auc: 0.710664
# Early stopping, best iteration is:
# [200]	train's auc: 0.718107	valid's auc: 0.713499
# [Batch 36] Validation AUC: 0.7135
# Training until validation scores don't improve for 10 rounds
# [210]	train's auc: 0.744655	valid's auc: 0.711692
# Early stopping, best iteration is:
# [202]	train's auc: 0.718401	valid's auc: 0.713459
# [Batch 37] Validation AUC: 0.7135
# Training until validation scores don't improve for 10 rounds
# [210]	train's auc: 0.733768	valid's auc: 0.711417
# Early stopping, best iteration is:
# [204]	train's auc: 0.711301	valid's auc: 0.713504
# [Batch 38] Validation AUC: 0.7135
# Training until validation scores don't improve for 10 rounds
# [210]	train's auc: 0.730793	valid's auc: 0.712387
# Early stopping, best iteration is:
# [205]	train's auc: 0.711243	valid's auc: 0.713267
# [Batch 39] Validation AUC: 0.7133
# Training until validation scores don't improve for 10 rounds
# [210]	train's auc: 0.730639	valid's auc: 0.712829
# Early stopping, best iteration is:
# [208]	train's auc: 0.72408	valid's auc: 0.713422
# [Batch 40] Validation AUC: 0.7134
# Training until validation scores don't improve for 10 rounds
# [210]	train's auc: 0.70997	valid's auc: 0.712788
# Early stopping, best iteration is:
# [209]	train's auc: 0.705357	valid's auc: 0.713037
# [Batch 41] Validation AUC: 0.7130
# [210]	train's auc: 0.717227	valid's auc: 0.713606
# Training until validation scores don't improve for 10 rounds
# [220]	train's auc: 0.750122	valid's auc: 0.711369
# Early stopping, best iteration is:
# [210]	train's auc: 0.717227	valid's auc: 0.713606
# [Batch 42] Validation AUC: 0.7136
# Training until validation scores don't improve for 10 rounds
# [220]	train's auc: 0.737496	valid's auc: 0.711746
# Early stopping, best iteration is:
# [212]	train's auc: 0.713024	valid's auc: 0.713679
# [Batch 43] Validation AUC: 0.7137
# Training until validation scores don't improve for 10 rounds
# [220]	train's auc: 0.727928	valid's auc: 0.712276
# Early stopping, best iteration is:
# [213]	train's auc: 0.704147	valid's auc: 0.713788
# [Batch 44] Validation AUC: 0.7138
# Training until validation scores don't improve for 10 rounds
# [220]	train's auc: 0.732417	valid's auc: 0.71315
# Early stopping, best iteration is:
# [215]	train's auc: 0.714314	valid's auc: 0.713942
# [Batch 45] Validation AUC: 0.7139
# Training until validation scores don't improve for 10 rounds
# [220]	train's auc: 0.723657	valid's auc: 0.713457
# Early stopping, best iteration is:
# [216]	train's auc: 0.708207	valid's auc: 0.714053
# [Batch 46] Validation AUC: 0.7141
# Training until validation scores don't improve for 10 rounds
# [220]	train's auc: 0.729735	valid's auc: 0.713523
# Early stopping, best iteration is:
# [218]	train's auc: 0.721611	valid's auc: 0.714046
# [Batch 47] Validation AUC: 0.7140
# Training until validation scores don't improve for 10 rounds
# [220]	train's auc: 0.713772	valid's auc: 0.714479
# [230]	train's auc: 0.744592	valid's auc: 0.711217
# Early stopping, best iteration is:
# [220]	train's auc: 0.713772	valid's auc: 0.714479
# [Batch 48] Validation AUC: 0.7145
# Training until validation scores don't improve for 10 rounds
# [230]	train's auc: 0.743457	valid's auc: 0.710652
# Early stopping, best iteration is:
# [221]	train's auc: 0.714957	valid's auc: 0.714485
# [Batch 49] Validation AUC: 0.7145
# Training until validation scores don't improve for 10 rounds
# [230]	train's auc: 0.741409	valid's auc: 0.712654
# Early stopping, best iteration is:
# [223]	train's auc: 0.718098	valid's auc: 0.714534
# [Batch 50] Validation AUC: 0.7145
# Training until validation scores don't improve for 10 rounds
# [230]	train's auc: 0.735418	valid's auc: 0.71476
# Early stopping, best iteration is:
# [227]	train's auc: 0.725206	valid's auc: 0.715001
# [Batch 51] Validation AUC: 0.7150
# Training until validation scores don't improve for 10 rounds
# [230]	train's auc: 0.718283	valid's auc: 0.714266
# Early stopping, best iteration is:
# [229]	train's auc: 0.714528	valid's auc: 0.714675
# [Batch 52] Validation AUC: 0.7147
# [230]	train's auc: 0.71295	valid's auc: 0.714742
# Training until validation scores don't improve for 10 rounds
# [240]	train's auc: 0.745716	valid's auc: 0.712861
# Early stopping, best iteration is:
# [230]	train's auc: 0.71295	valid's auc: 0.714742
# [Batch 53] Validation AUC: 0.7147
# Training until validation scores don't improve for 10 rounds
# [240]	train's auc: 0.73758	valid's auc: 0.713327
# Early stopping, best iteration is:
# [231]	train's auc: 0.707619	valid's auc: 0.714837
# [Batch 54] Validation AUC: 0.7148
# Training until validation scores don't improve for 10 rounds
# [240]	train's auc: 0.739039	valid's auc: 0.713869
# Early stopping, best iteration is:
# [232]	train's auc: 0.711059	valid's auc: 0.714497
# [Batch 55] Validation AUC: 0.7145
# Training until validation scores don't improve for 10 rounds
# [240]	train's auc: 0.739152	valid's auc: 0.714696
# Early stopping, best iteration is:
# [238]	train's auc: 0.733642	valid's auc: 0.714916
# [Batch 56] Validation AUC: 0.7149
# Training until validation scores don't improve for 10 rounds
# [240]	train's auc: 0.710242	valid's auc: 0.715207
# [250]	train's auc: 0.739959	valid's auc: 0.713633
# Early stopping, best iteration is:
# [240]	train's auc: 0.710242	valid's auc: 0.715207
# [Batch 57] Validation AUC: 0.7152
# Training until validation scores don't improve for 10 rounds
# [250]	train's auc: 0.781328	valid's auc: 0.708679
# Early stopping, best iteration is:
# [241]	train's auc: 0.721354	valid's auc: 0.715697
# [Batch 58] Validation AUC: 0.7157
